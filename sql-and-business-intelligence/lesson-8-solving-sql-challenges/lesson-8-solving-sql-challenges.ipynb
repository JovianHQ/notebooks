# %% [markdown]
# # SQL Practice Questions
#
# ![](https://resources.biginterview.com/wp-content/uploads/2014/09/sql-interview-questions.png)

# %% [markdown]
# SQL is an essential language used for managing relational databases. We have curated 30 SQL practice questions of varying difficulty levels to help individuals improve their SQL coding skills. These questions are designed to test your knowledge of SQL syntax and help you practice writing effective SQL queries that retrieve, filter, and sort data from a database.
#
# By practicing these SQL practice questions, you can gain a better understanding of SQL syntax, build a strong foundation in SQL, and prepare for job interviews, coding challenges, or real-world projects that involve working with databases. With a range of questions designed to challenge individuals at every level, these SQL practice questions are an excellent way to improve your SQL skills and become a more proficient SQL coder.

# %% [markdown]
# | # | Challenge | Link |
# |---|-----------|------|
# | 1 | Revising the SELECT query | [HackerRank](https://www.hackerrank.com/challenges/revising-the-select-query?isFullScreen=true) |
# | 2 | Revising the SELECT query 2 | [HackerRank](https://www.hackerrank.com/challenges/revising-the-select-query-2?isFullScreen=true) |
# | 3 | SELECT all | [HackerRank](https://www.hackerrank.com/challenges/select-all-sql?isFullScreen=true) |
# | 4 | SELECT By ID | [HackerRank](https://www.hackerrank.com/challenges/select-by-id?isFullScreen=true) |
# | 5 | Japanese Cities' Attributes | [HackerRank](https://www.hackerrank.com/challenges/japanese-cities-attributes?isFullScreen=true) |
# | 6 | Japanese Cities' Names | [HackerRank](https://www.hackerrank.com/challenges/japanese-cities-name?isFullScreen=true) |
# | 7 | Weather Observation Station | [HackerRank](https://www.hackerrank.com/challenges/weather-observation-station-1?isFullScreen=true) |
# | 8 | Duplicate Emails | [LeetCode](https://leetcode.com/problems/duplicate-emails/) |
# | 9 | Customer Placing the Largest Number of Orders | [LeetCode](https://leetcode.com/problems/customer-placing-the-largest-number-of-orders/) |
# | 10 | Actors & Directors | [LeetCode](https://leetcode.com/problems/actors-and-directors-who-cooperated-at-least-three-times/) |
# | 11 | Sales Analysis III | [LeetCode](https://leetcode.com/problems/sales-analysis-iii/) |
# | 12 | Top Travellers | [LeetCode](https://leetcode.com/problems/top-travellers/) |
# | 13 | Customer Details | [StrataScratch](https://platform.stratascratch.com/coding/9891-customer-details?code_type=3) |
# | 14 | Salaries Differences | [StrataScratch](https://platform.stratascratch.com/coding/10308-salaries-differences?code_type=3) |
# | 15 | Occupations | [HackerRank](https://www.hackerrank.com/challenges/occupations/problem) |
# | 16 | New Companies | [HackerRank](https://www.hackerrank.com/challenges/the-company/problem?isFullScreen=true) |
# | 17 | Weather Observation Station 20 | [HackerRank](https://www.hackerrank.com/challenges/weather-observation-station-20/problem?isFullScreen=true) |
# | 18 | Placements | [HackerRank](https://www.hackerrank.com/challenges/placements/problem?isFullScreen=true) |
# | 19 | Weather Observation Station 18 | [HackerRank](https://www.hackerrank.com/challenges/weather-observation-station-18?isFullScreen=true) |
# | 20 | Weather Observation Station 19 | [HackerRank](https://www.hackerrank.com/challenges/weather-observation-station-19?isFullScreen=true) |
# | 21 | Contest Leaderboard | [HackerRank](https://www.hackerrank.com/challenges/contest-leaderboard?isFullScreen=true) |
# | 22 | English, German, French, Spanish | [StrataScratch](https://platform.stratascratch.com/coding/9668-english-german-french-spanish-speakers?code_type=3) |
# | 23 | Department Top Three Salaries | [LeetCode](https://leetcode.com/problems/department-top-three-salaries/) |
# | 24 | Top Percentile Fraud | [StrataScratch](https://platform.stratascratch.com/coding/10303-top-percentile-fraud?python=&code_type=3) |
# | 25 | Monthly Percentage Difference | [StrataScratch](https://platform.stratascratch.com/coding/10319-monthly-percentage-difference?code_type=3) |
# | 26 | Distance Per Dollar | [StrataScratch](https://platform.stratascratch.com/coding/10302-distance-per-dollar?code_type=3) |
# | 27 | Popularity Percentage | [StrataScratch](https://platform.stratascratch.com/coding/10284-popularity-percentage?code_type=3) |
# | 28 | Interviews | [HackerRank](https://www.hackerrank.com/challenges/interviews/problem) |
# | 29 | 15 Days of Learning SQL | [HackerRank](https://www.hackerrank.com/challenges/15-days-of-learning-sql/problem) |
