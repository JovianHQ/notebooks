# %% [markdown]
# # Subarray with Given Sum
#
# <a target="_blank" href="https://colab.research.google.com/github/JovianHQ/notebooks/blob/main/data-structures-and-algorithms-in-python/lesson-6-python-interview-questions-tips-advice/python-subarray-with-given-sum.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# > You are given an array of numbers (non-negative). Find a continuous subarray of the list which adds up to a given sum.
#
#
# ![](https://i.imgur.com/tLEBF7x.png)
