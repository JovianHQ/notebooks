# %% [markdown]
# # Title Here
#
# <a target="_blank" href="https://colab.research.google.com/github/JovianHQ/notebooks/blob/main/deep-learning-with-pytorch-zero-to-gans/assignment-1-all-about-torch-tensor/01-tensor-operations.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# ### Subtitle Here
#
# An short introduction about PyTorch and about the chosen functions.
# - function 1
# - function 2
# - function 3
# - function 4
# - function 5

# %%
# Import torch and other required modules
import torch

# %% [markdown]
# ## Function 1 - torch.tensor (change this)
#
# Add some explanations

# %%
# Example 1 - working (change this)
torch.tensor([[1, 2], [3, 4.]])
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %% [markdown]
# Explanation about example

# %%
# Example 2 - working

# %% [markdown]
# Explanation about example

# %%
# Example 3 - breaking (to illustrate when it breaks)
torch.tensor([[1, 2], [3, 4, 5]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-28787d136593> in <module>
#       1 # Example 3 - breaking (to illustrate when it breaks)
# ----> 2 torch.tensor([[1, 2], [3, 4, 5]])
#
# ValueError: expected sequence of length 2 at dim 1 (got 3)

# %% [markdown]
# Explanation about example

# %% [markdown]
# Closing comments about when to use this function

# %% [markdown]
# ## Function 2 - ???
#
# Add some explanations

# %%
# Example 1 - working

# %% [markdown]
# Explanation about example

# %%
# Example 2 - working

# %% [markdown]
# Explanation about example

# %%
# Example 3 - breaking (to illustrate when it breaks)

# %% [markdown]
# Explanation about example

# %% [markdown]
# Closing comments about when to use this function

# %% [markdown]
# ## Function 3 - ???
#
# Add some explanations

# %%
# Example 1 - working

# %% [markdown]
# Explanation about example

# %%
# Example 2 - working

# %% [markdown]
# Explanation about example

# %%
# Example 3 - breaking (to illustrate when it breaks)

# %% [markdown]
# Explanation about example

# %% [markdown]
# Closing comments about when to use this function

# %% [markdown]
# ## Function 4 - ???
#
# Add some explanations

# %%
# Example 1 - working

# %% [markdown]
# Explanation about example

# %%
# Example 2 - working

# %% [markdown]
# Explanation about example

# %%
# Example 3 - breaking (to illustrate when it breaks)

# %% [markdown]
# Explanation about example

# %% [markdown]
# Closing comments about when to use this function

# %% [markdown]
# ## Function 5 - ???
#
# Add some explanations

# %%
# Example 1 - working

# %% [markdown]
# Explanation about example

# %%
# Example 2 - working

# %% [markdown]
# Explanation about example

# %%
# Example 3 - breaking (to illustrate when it breaks)

# %% [markdown]
# Explanation about example

# %% [markdown]
# Closing comments about when to use this function

# %% [markdown]
# ## Conclusion
#
# Summarize what was covered in this notebook, and where to go next

# %% [markdown]
# ## Reference Links
# Provide links to your references and other interesting articles about tensors
# * Official documentation for `torch.Tensor`: https://pytorch.org/docs/stable/tensors.html
# * ...
