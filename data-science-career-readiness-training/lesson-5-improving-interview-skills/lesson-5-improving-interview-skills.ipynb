# %% [markdown]
# # interivew-basics
#
# Use the "Run" button to execute the code.

# %% [markdown]
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vT7iwTphUqOd5GyMSXZxwCGjUdPsdRMY5fA991IpTmEaI9UAhaUpL5eiXNepYiNcrmpaRtfqQybW9l7/embed?start=false&loop=false&delayms=3000" width="800" height="600" allowfullscreen="true"></iframe>
