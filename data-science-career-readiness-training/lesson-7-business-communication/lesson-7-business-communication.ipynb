# %% [markdown]
# # Business Communication

# %% [markdown]
# <div style="position: relative; padding-bottom: 56.25%; height: 0; overflow: hidden;">
#     <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vSFNekzA8AzXuCSXQC8z-ycaAlstR15jsmiQ-Rt9YyvS24WrFweiVlgnQemnYYuTS92n9aONPM8ojyn/embed?start=false&loop=false&delayms=3000" style="position: absolute; top: 0; left: 0; width: 100%; height: 100%;" allowfullscreen="true" frameborder="0"></iframe>
# </div>
