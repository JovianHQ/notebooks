# %% [markdown]
# # Communication Basics & Impromptu Speaking

# %% [markdown]
# <div style="position: relative; padding-bottom: 56.25%; height: 0; overflow: hidden;">
#     <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vS17VZ5TiTQQ6r1pWugjZLWzFmps_2PoZdIO39NmttU8ozrEakq7QAdtvtXxXYIIKTgg7TYwfu5pWlq/embed?start=false&loop=false&delayms=3000" style="position: absolute; top: 0; left: 0; width: 100%; height: 100%;" allowfullscreen="true" frameborder="0"></iframe>
# </div>
